# %%
pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in c:\users\hp\anaconda3\lib\site-packages (2.106.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in c:\users\hp\anaconda3\lib\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in c:\users\hp\anaconda3\lib\site-packages (from google-api-python-client) (2.23.4)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\hp\anaconda3\lib\site-packages (from google-api-python-client) (0.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\hp\anaconda3\lib\site-packages (from google-api-python-client) (2.12.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\hp\anaconda3\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\hp\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.61.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\hp\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.25.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\hp\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hp\anaconda3\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hp\anaconda3\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\hp\anaconda3\lib\site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\hp\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
from googleapiclient.discovery import build

# Set up the YouTube Data API
api_key = "AIzaSyBzWChHTCmb1SQESD2Zon1UrDbI_EXPeSM"
youtube = build('youtube', 'v3', developerKey=api_key)

# Set the channel ID
#channel_id = "UCsS-x_cwLNz4PhRwzRRLoXQ"

channel_id = "UCWv7vMbMWH4-V0ZXdmDpPBA"

# Call the API to get the comments
comments = youtube.commentThreads().list(
    part="snippet",
    allThreadsRelatedToChannelId=channel_id,
    maxResults=100
).execute()

# Process the comments
for comment in comments['items']:
    print(comment['snippet']['topLevelComment']['snippet']['textDisplay'])
# Out:
# Thank you very much Mosh, excellent video and the pdf guide for me as system administrator and network manager.
# Thank U Mosh, Ive read the most of the coments and I see  a lot of gratitude, so here is mine. Thank you for  sharing your knowledge and giving us hope. from Mexico City.
# <br>print(name,age,status)
# Sir make video on kotlin
# Well done my teacher Arl episode I watch and I will subscribe to your channel because of the Arabic translation that you did to have mercy on him listen ❤
# <br>        print(&quot;Please enter a valid number&quot;)
# Taylor David Lee Sharon Martinez Sandra
# 6 hours!!!!! Super thanks!!! 🙏🙏🙏
# For the weight solution I came up with<br>weight = int(float(input(&quot;what is your weight? &quot;)))<br>print(weight//2.205)
# Melba Manor
# I don&#39;t know if something changed in python but at <a href="https://www.youtube.com/watch?v=kqtD5dpn9C8&amp;t=1102">18:22</a> u used print (&quot;sum&quot; +str(sum)) but I used print(&quot;sum&quot;, sum) and got the same results
# anyone got the complete C++ video 😭😭?
# Wonderful, you are Excellent and I would go forward and take the other courses, Thank you very much
# Web Development
# Rodriguez Frank Williams Karen Hall Charles
# It took a few clicks. But at last I have my cheat sheets. I say cheat sheets plural since it&#39;s actually a fourteen page reference. Mosh you obviously put a lot of time and effort into the reference as you did this video. You love coding and programming. And since you love it, I love it as well. Your teaching style motivates me to learn. This video is an antidote to boredom!  You keep things interesting. Though I have the cheat, yet I have downloaded the transcript so that I can highlight, italicize, bold or underline concepts that I think are critical to my understanding of the material. I&#39;m trying to flowchart as well. That way when I run into problems, it&#39;s easy to trace back through the logic. I think that I want to do some penetration testing, some app development and some back end development. We&#39;ll see. Hey man, thanks for all that you do!
# Miller Shirley Allen Mary Wilson Jessica
# thanks for adding Arabic language
# got cheated XD
# How we convert this all python project to real world
# Thanks!
# I love it 😍
# Harris Jason Thomas Daniel White Jeffrey
# Hey i am not receiving the cheat sheet on mail pls help
# <a href="https://www.youtube.com/watch?v=_uQrJ0TkZlc&amp;t=785">13:05</a><br>I&#39;ve always wanted to be a Game developer <br>I don&#39;t even have a computer 😂😂😅
# Hi, <br><br>thank you for providing us with so much useful content! <br><br>So, I&#39;ve tried to code the patients&#39; list at <a href="https://www.youtube.com/watch?v=kqtD5dpn9C8&amp;t=529">8:49</a>. Here is what I wrote:<br><br>print(&quot;patient data&quot;)<br>first_name = print(&quot;John&quot;)<br>second_name = print(&quot;Smith&quot;)<br>age = 20<br>status = print(&quot;new patient&quot;)<br>print(age)<br><br>Is this right or are there any mistakes in my code?<br><br>There are no issues when I run the code so far.
# To be fair, half of this is python beginner course, so ... kinda disappointing
# Turkey 🇹🇷
# Crooks Lodge
# Beahan Field
# Eliezer Mews
# can you remove ting ting music in mid when header opos up it breaks concentration
# I completely disagree with you. People aren’t stupid animals who are incapable of reasoning through things themselves when something works or doesn’t work. Yes absolutely you should be using AI to learn how to code because you can ask questions. Ask to clarify point out inconsistencies and have a conversation with it in which it acknowledges that it was wrong when it reviews what you point out. This means that you can get bad code from ChatGPT and say hey this isn’t working or I thought it was supposed to be a different way what what’s going on there and for the most part it’s gonna tell you my bad you’re correct. By telling people not to use AI to learn to code, you’re basically acting like people are too fucking stupid to understand complex things. It’s not about AI being perfect. It’s about how you grow and learn as an individual overtime and ChatGPT is wonderful for that. Especially for software developers.
# 牛哇，有中文音频资源！！！必须给MOSH大神点赞！！！
# well, you&#39;ve got my attention mate! Subscribed!
# <a href="https://www.youtube.com/watch?v=d56mG7DezGs&amp;t=3681">1:01:21</a> We can do this in js too, right?
# thank you
# Excelente video, mañana mismo voy a empezar a aprender C#. Deséenme suerte, la voy a necesitar.
# Tamil Language (India)
# All developers now
# Moore Patricia Smith Daniel Thomas Maria
# I am learning python for Artificial Intelligence (AI)
# how did you open the conditions.text at <a href="https://www.youtube.com/watch?v=_uQrJ0TkZlc&amp;t=3643">1:00:43</a>
# This video taught me more about coding and game design than the past 5 years of Codecademy. Thank you Mosh!
# I love your video especially for this parT! @<a href="https://www.youtube.com/watch?v=7eh4d6sabA0&amp;t=1461">24:21</a> THANK YOU!
# 125 Runolfsdottir Plains
# <br>we have 4 even numbers
# Anyone else here in 2024  (Near 2025)? <br><br>Btw, this is amazing.
# Can someone help me? I did everything in the comparison operator assignment but got &#39;str&#39; is not callable. How can I rectify this??<br>PS: I&#39;m using jupyter for the lessons
# This is for data science not for the data analysis role.
# Im studying informatics since 24 years now. I tried literally everything including Mosh videos, Bachelor, Master, Plenty of Udemy Videos, countless hours  projects and applies for a job. All I managed was 5 interviews from which I was rejected. I applied for 2.500 jobs for real! Alone and with help of many prof.. covering whole Greece and Germany
# AM learning it for machine learning
# Tillman Ramp
# I want to use Python for Computer programing.<br>what are things you would recommend for me?<br>Also my goal is to start collage next year January.
# please more video like this
# Donnie Unions
# Thanks for helping us.🙏. You are the best teacher ❤. I watch your videos every day
# python &amp; java script
# name = John Smith<br>Print (&quot;name&quot;)<br>age = 20<br>Print(&quot;age&quot;)<br>patient_type = new_patient<br>Print(&quot;patient_type&quot;)
# Gng i regret choosing computer as my subject 😸
# you saved my life rlly
# I&#39;m so exactly excited ☺ this Video really I understood My best thanks for free this course.
# <br><a href="http://googleads.g.doubleclick.net/pagead/id:1">googleads.g.doubleclick.net/pagead/id:1</a>
# <br><a href="http://play.google.com/log?format=json&amp;hasfast=true&amp;authuser=0:1">play.google.com/log?format=json&amp;hasfast=true&amp;authuser=0:1</a>
# 0030 Timothy Villages
# Thank you so much Mosh!
# Thanks Mosh for your efforts. I hope you make a project focused on OOP in Python
# i am not able to access spreadsheets with python code. please help
# And here I was writing my basic template every time 😅
# &#39;lnt&#39; in full is<br>I didn&#39;t get the name please
# <br>    print (&quot;Your weight in LBs is &quot; + str(LBS))
# Откуда ты берешь информацию про все это? И как её правильно искать?
# Hello,  thanks for your road map
# &lt;!DOCTYPE html&gt;<br><br>&lt;html&gt;<br><br>&lt;body&gt;<br><br>&amp;nbsp; &amp;nbsp; &amp;nbsp; &amp;nbsp; &amp;nbsp; &amp;nbsp;&lt;b&gt;Multiplication &lt;br&gt; &lt;br&gt; &lt;br&gt;&lt;br&gt;<br><br>Enter the first number:&amp;nbsp;&lt;input type=&quot;text&quot; id=&quot;txtbox1&quot; /&gt;&lt;br&gt; &lt;br&gt; Enter the Second number:&amp;nbsp;&lt;input type=&quot;text&quot; id=&quot;txtbox2&quot; /&gt;&lt;br&gt; &lt;br&gt;<br><br>&lt;p id=&quot;demo&quot;&gt;&lt;/p&gt;<br><br>&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&lt;button onclick=&quot;myFunction()&quot;&gt;Test&lt;/button&gt;<br><br>&lt;script&gt;<br><br>/*<br><br>// ES5<br><br>var x = function(x, y) {<br><br>return x * y;<br><br>}<br><br>// ES6<br><br>const x = (x, y) =&gt; x * x; */<br><br>function myFunction() {<br><br>var fvalue = document.getElementById(&quot;txtbox1&quot;).value;<br><br>var svalue = document.getElementById(&quot;txtbox2&quot;).value;<br><br>const multiply = (x, y) =&gt; x * y;<br><br>document.getElementById(&quot;demo&quot;).innerHTML = multiply(fvalue, svalue);<br><br>}<br><br>&lt;/script&gt;<br><br>&lt;/body&gt;<br><br>&lt;/html&gt;
# &lt;html&gt;<br><br>&lt;body&gt;<br><br>&lt;div id=&quot;demo&quot;&gt;<br><br>&lt;h2&gt;The XMLHttpRequest Object&lt;/h2&gt;<br><br>&lt;button type=&quot;button&quot; onclick=&quot;loadDoc()&quot;&gt;Change Content&lt;/button&gt;<br><br>&lt;/div&gt;<br><br>&lt;script&gt;<br><br>function loadDoc() {<br><br>const xhttp = new XMLHttpRequest();<br><br>xhttp.onload = function() {<br><br>document.getElementById(&quot;demo&quot;).innerHTML = this.responseText;<br><br>}<br><br>xhttp.open(&quot;GET&quot;, &quot;newfile.txt&quot;);<br><br>xhttp.send();<br><br>}<br><br>&lt;/script&gt;<br><br>&lt;/body&gt;<br><br>&lt;/html&gt;
# &lt;html&gt;<br><br>&lt;head&gt;<br><br>&lt;title&gt;DOM and Events&lt;/title&gt;<br><br>&lt;style&gt;<br><br>* {<br><br>font-family: -apple-system, BlinkMacSystemFont, &#39;Segoe UI&#39;, Roboto, Oxygen, Ubuntu, Cantarell, &#39;Open Sans&#39;, &#39;Helvetica Neue&#39;, sans-serif;<br><br>{<br><br>&lt;/style&gt;<br><br>&lt;/head&gt;<br><br>&lt;body&gt;<br><br>&lt;h3&gt;<br><br>Message will be displayed when you press a Enter key &lt;/h3&gt; &lt;input type=&quot;text&quot; class=&quot;inputArea&#39;<br><br>&lt;p&gt;&lt;/p&gt;<br><br>&lt;script&gt;<br><br>let input = document.querySelector(&quot;.inputArea&quot;); let p = document.querySelector(&quot;p&quot;);<br><br>input.addEventListener(&#39;change&#39;, function() {<br><br>input.style.color = &quot;red&quot;;<br><br>})<br><br>input.addEventListener(&#39;focus&#39;, function() {<br><br>input.style.color = &quot;black&quot;;<br><br>})
# Bartoletti Points
# Is this guy Indian?
# I waching this Video in 2025😂 And Also In 2026 B/s  Use Full Video And It Must For Developer.
# I wsnt ro impress my friends thats why im learning this😅
# You mentioned about console, in an equal size command center station computer enclosed console, a Drone spacecraft in space area of optional crew pilot or AI co pilot, the crew seats can be saturated with energy with synched codes to the base then teleport the pilot from light-years away into the drone spacecraft like Hi- Hoo Silver said by a tv cowboy galactic jump into his horse galloping to glory.
# Lubowitz Rest
# Gwapo ka daw Mr Mosh sabi Ng bading sa tv, parang mas guwapo yata ako Sayo. No offense meant.
# Mr. Mosh Hamedani, you&#39;re a look alike actor of a tall syndicate head shaved skull who had a gunfight with Tanggol with Rosanna Rocess in Batang Quiapo teleserye in Tv series. Though I cannot conceive why it&#39;s called Bata ( child ), there&#39;s no toddler in that show I can remember.
# I previously had ordered stations of floating space nodes by creating it&#39;s own atomic nucleus, protons, neutrons, electrons instilled ordered to my scientists for space internet usage to make those things float. Wherein beams of neuron like beams interconnect enabling those nodes to appear like neutron body, dendrites, synapses and axons in space, for connectivity, energy chargings and for future space area shortcut portals by quantum particles effect. Like stations of nodes with network like spiderweb projection in each node.
# Something I remember, like the technique of a being to disrupt a reality he is talking about not to be analyzed quick by blinking the eyes when talking with someone, that&#39;s a method within a method, of a Quantum Engineering or Quantum particles in itself, this is not related to your lecture, I was only reminded by something in the past.
# I love you mosh so much. You beautiful creature! Love from Bharat.
# Emojis on windows type Windows logo key +. (period).
# Where can I find the github repos ?
# Who is here in 2024?
# Which tutorial do you suggest for lung nodule segmentation, Kindly help..
# Nolan Isle
# I think for newbies, &quot;JavaScript and TypeScript Nightly&quot; extension is not needed right?
# Do u have some tutorial for lu ng nodule segmentation?

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\hp\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\hp\anaconda3\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.65.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from textblob import TextBlob
from googleapiclient.discovery import build

# Set up the YouTube Data API
api_key = "AIzaSyBzWChHTCmb1SQESD2Zon1UrDbI_EXPeSM"
youtube = build('youtube', 'v3', developerKey=api_key)

# Set the channel ID
channel_id = "UCkLXELm63_pH7L-r-548kig"

# Call the API to get the comments
comments = youtube.commentThreads().list(
    part="snippet",
    allThreadsRelatedToChannelId=channel_id,
    maxResults=100
).execute()

# Perform sentiment analysis
positive_comments = 0
negative_comments = 0

for comment in comments['items']:
    text = comment['snippet']['topLevelComment']['snippet']['textDisplay']
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        positive_comments += 1
    elif analysis.sentiment.polarity < 0:
        negative_comments += 1

# Display results in a graph
labels = ['Positive Comments', 'Negative Comments']
sizes = [positive_comments, negative_comments]
colors = ['#7d7d7d', '#c3c2c2']
explode = (0.1, 0)  

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('Sentiment Analysis of YouTube Comments')
plt.show()
